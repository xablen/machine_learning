# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.cross_validation import train_test_split
from sklearn.neighbors import KNeighborsClassifier

# %%
house_data_raw = pd.read_csv('C:\Users\Xavier\Desktop\ipython\house_data.csv')
house_data = house_data_raw[house_data_raw['surface'] > 1]
house_data = house_data_raw[house_data_raw['price'] < 7000]
x = house_data['price']
y = house_data['surface']

# %%
print house_data_raw.shape
print house_data.shape
# Out:
# (827, 3)
# (813, 3)

# %%
plt.plot(house_data['surface'], house_data['price'], 'ro', markersize=4)
plt.show()

# %%
X = np.matrix([np.ones(house_data.shape[0]), house_data['surface'].as_matrix()]).T
y = np.matrix(house_data['price']).T

theta = np.linalg.inv(X.T.dot(X)).dot(X.T).dot(y)

print(theta)
# Out:
# [[ nan]
#  [ nan]]

# %%
knn = KNeighborsClassifier(3)
knn.fit(xtrain, ytrain)
# Out:
# c:\python27\lib\site-packages\sklearn\utils\validation.py:395: DeprecationWarning: Passing 1d arrays as data is deprecated in 0.17 and will raise ValueError in 0.19. Reshape your data either using X.reshape(-1, 1) if your data has a single feature or X.reshape(1, -1) if it contains a single sample.
#   DeprecationWarning)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-108-0dc53fdbd794> in <module>()
#       1 knn = KNeighborsClassifier(3)
# ----> 2 knn.fit(xtrain, ytrain)
#
# c:\python27\lib\site-packages\sklearn\neighbors\base.pyc in fit(self, X, y)
#     759         """
#     760         if not isinstance(X, (KDTree, BallTree)):
# --> 761             X, y = check_X_y(X, y, "csr", multi_output=True)
#     762
#     763         if y.ndim == 1 or y.ndim == 2 and y.shape[1] == 1:
#
# ...
